# %% [markdown]
# # Lab 2 - Exploring Joining strategies
#
# In this lab, we will investigate the joining of the property data from 2004-2015 to the water quality data.  First, we need to
#
# 1. Understand the big picture and determine the key(s) used to join tables.
# 2. Understand the relationship between tables (one-to-one; one-to-many; many-to-many), and
# 3. Pick a join type and investigate key mismatches.

# %% [markdown]
# ## Problem 1 - Understanding the big picture and tables keys
#
# ![image.png](attachment:image.png)
#
# **Task.**  The picture shown above provides a high-level view of the joining process. Remember that our goal is to explain changes in water quality in various lakes over time.  What do you think the structure of the final table should be?  One row per what? Describe some examples of the sort of columns you would want present in this file.

# %% [markdown]
# > <font color="orange"> Your thoughts here </font>
# The structure of the final table should be a column with year, and a column with lake quality. The tables should be joined so that the data has one row per year, some columns I want present are the year, the lake, the quality overall for the lake.

# %% [markdown]
# ## Problem 2 - Understanding the big picture and tables keys
#
# **Tasks.**  Perform each of the following task.  Any task that requires data management should be performed separately in both `polars` and `pandas` using lazy data frames.
#
# 1. Use a lazy data frame to inspect the columns and a few rows of data.
# 2. Suggest the columns that will be used as keys to join the tables.
# 3. One set of keys are floating point numbers (which?).  Discuss the potential problems with using floating point numbers as keys.  Suggest possible remedies.
# 3. To understand the relationship (one-to-one; one-to-many; many-to-many) between tables, select the key columns, perform aggregation on each table to determine if there is one or many keys per row.
# 4. Based on the results of the last task, suggest a join type and justify your response.

# %%
from data.column_data import cols_to_keep
from data.columns import column_schema

# %%
import polars as pl
import polars.selectors as cs
from glob import glob
import re

# %%
glob('data/**/*.txt', recursive=True)
# Out:
# ['data/MinneMUDAC_raw_files/mces_lakes_1999_2014.txt',
#  'data/MinneMUDAC_raw_files/2015_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2003_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/mces_lakes_1999_2014_v2.txt',
#  'data/MinneMUDAC_raw_files/2014_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2009_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/Parcel_Lake_Monitoring_Site_Xref.txt',
#  'data/MinneMUDAC_raw_files/2008_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2006_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2007_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2002_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2011_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2013_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2002_metro_tax_parcels_v2.txt',
#  'data/MinneMUDAC_raw_files/2005_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2004_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2010_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2012_metro_tax_parcels.txt']

# %%
schema_override = {'latitude': pl.String(), 'longitude': pl.String()}

(mces_lakes := (
    pl.scan_csv(
        'data/MinneMUDAC_raw_files/mces_lakes_1999_2014_v2.txt',
        has_header=True,
        separator='\t',
        infer_schema_length=10000,
        schema_overrides=schema_override
    )
    .limit(100)
    .collect()
))
# Out:
# shape: (0, 1_544_257)
# ┌────────────┬────────────┬───────────┬──────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ PROJECT_ID ┆ DATA_SET_T ┆ LAKE_NAME ┆ CITY ┆ … ┆ Approved_d ┆ mg/L_dupli ┆ -93.66768 ┆ 44.883817 │
# │ ---        ┆ ITLE       ┆ ---       ┆ ---  ┆   ┆ uplicated_ ┆ cated_4825 ┆ 906_dupli ┆ 17        │
# │ str        ┆ ---        ┆ str       ┆ str  ┆   ┆ 141567     ┆ 5          ┆ cated_79  ┆ ---       │
# │            ┆ str        ┆           ┆      ┆   ┆ ---        ┆ ---        ┆ ---       ┆ str       │
# │            ┆            ┆           ┆      ┆   ┆ str        ┆ str        ┆ str       ┆           │
# ╞════════════╪════════════╪═══════════╪══════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# └────────────┴────────────┴───────────┴──────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
(parcel_lake_xref := (
    pl.scan_csv(
        'data/MinneMUDAC_raw_files/Parcel_Lake_Monitoring_Site_Xref.txt',
        has_header=True,
        separator='\t',
        infer_schema_length=10000
    )
    .limit(100)
    .collect()
))
# Out:
# shape: (100, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Parcel_PI ┆ Monit_MAP ┆ Monit_SIT ┆ Monit_LAK ┆ … ┆ Distance_ ┆ centroid_ ┆ centroid_ ┆ Parcel_p │
# │ N         ┆ _CODE1    ┆ E_CODE    ┆ E_SITE    ┆   ┆ Parcel_La ┆ long      ┆ lat       ┆ key      │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ke_meters ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ i64       ┆ i64       ┆   ┆ ---       ┆ f64       ┆ f64       ┆ i64      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ null      ┆ 19007900- ┆ 19007900  ┆ 1         ┆ … ┆ 2571.5267 ┆ -93.11451 ┆ 44.94283  ┆ 2163034  │
# │           ┆ 01        ┆           ┆           ┆   ┆ 92        ┆           ┆           ┆          │
# │ null      ┆ 19007900- ┆ 19007900  ┆ 1         ┆ … ┆ 2515.3738 ┆ -93.11539 ┆ 44.94234  ┆ 2163035  │
# │           ┆ 01        ┆           ┆           ┆   ┆ 02        ┆           ┆           ┆          │
# │ null      ┆ 19007900- ┆ 19007900  ┆ 1         ┆ … ┆ 2511.9249 ┆ -93.11556 ┆ 44.94231  ┆ 2163036  │
# │           ┆ 01        ┆           ┆           ┆   ┆ 59        ┆           ┆           ┆          │
# │ null      ┆ 19007900- ┆ 19007900  ┆ 1         ┆ … ┆ 2502.9916 ┆ -93.11572 ┆ 44.94223  ┆ 2163037  │
# │           ┆ 01        ┆           ┆           ┆   ┆ 4         ┆           ┆           ┆          │
# │ null      ┆ 19007900- ┆ 19007900  ┆ 1         ┆ … ┆ 2465.2062 ┆ -93.1158  ┆ 44.94189  ┆ 2163038  │
# │           ┆ 01        ┆           ┆           ┆   ┆ 34        ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ null      ┆ 02004200- ┆ 2004200   ┆ 1         ┆ … ┆ 2270.7623 ┆ -93.2247  ┆ 45.32081  ┆ 1917269  │
# │           ┆ 01        ┆           ┆           ┆   ┆ 37        ┆           ┆           ┆          │
# │ null      ┆ 02005300- ┆ 2005300   ┆ 1         ┆ … ┆ 4417.5285 ┆ -93.22211 ┆ 45.30155  ┆ 1917270  │
# │           ┆ 01        ┆           ┆           ┆   ┆ 19        ┆           ┆           ┆          │
# │ null      ┆ 02005300- ┆ 2005300   ┆ 1         ┆ … ┆ 4291.8168 ┆ -93.21673 ┆ 45.30076  ┆ 1917271  │
# │           ┆ 01        ┆           ┆           ┆   ┆ 78        ┆           ┆           ┆          │
# │ null      ┆ 02009100- ┆ 2009100   ┆ 3         ┆ … ┆ 6096.1715 ┆ -93.26157 ┆ 45.32293  ┆ 1917272  │
# │           ┆ 03        ┆           ┆           ┆   ┆ 68        ┆           ┆           ┆          │
# │ null      ┆ 02009100- ┆ 2009100   ┆ 3         ┆ … ┆ 5851.7257 ┆ -93.26522 ┆ 45.32295  ┆ 1917273  │
# │           ┆ 03        ┆           ┆           ┆   ┆ 03        ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ## Problem 3 - Make join key indicator tables - Water Quality VS XREF
#
# Now that you have identified the keys for joining the water quality file with the XREF, make an indicator column table as shown below.
#
# ![image.png](attachment:image.png)
#
# Use this table to explore all mismatches

# %%
# Your code here
water_quality_keys = (
    pl.scan_csv(
        "data/MinneMUDAC_raw_files/mces_lakes_1999_2014.txt",
        has_header=True,
        separator='\t',
        infer_schema_length=10000,
        schema_overrides={'latitude': pl.String(), 'longitude': pl.String()}
    )
    .select(['DNR_ID_Site_Number', 'LAKE_NAME'])
    .unique()
    .with_columns(pl.lit(1).alias('water_quality'))
    .collect()
)
water_quality_keys
# Out:
# shape: (0, 3)
# ┌────────────────────┬───────────┬───────────────┐
# │ DNR_ID_Site_Number ┆ LAKE_NAME ┆ water_quality │
# │ ---                ┆ ---       ┆ ---           │
# │ str                ┆ str       ┆ i32           │
# ╞════════════════════╪═══════════╪═══════════════╡
# └────────────────────┴───────────┴───────────────┘

# %%
xref_keys = (
    pl.scan_csv(
        'data/MinneMUDAC_raw_files/Parcel_Lake_Monitoring_Site_Xref.txt',
        has_header=True,
        separator='\t'
    )
    .select(['Monit_MAP_CODE1'])
    .unique()
    .with_columns(pl.lit(1).alias('xref'))
    .collect()
)
xref_keys
# Out:
# shape: (440, 2)
# ┌─────────────────┬──────┐
# │ Monit_MAP_CODE1 ┆ xref │
# │ ---             ┆ ---  │
# │ str             ┆ i32  │
# ╞═════════════════╪══════╡
# │ 19005100-01     ┆ 1    │
# │ 19009500-01     ┆ 1    │
# │ 02000900-01     ┆ 1    │
# │ 27005700-01     ┆ 1    │
# │ 82004800-01     ┆ 1    │
# │ …               ┆ …    │
# │ 82009900-02     ┆ 1    │
# │ 19008200-01     ┆ 1    │
# │ 82008000-01     ┆ 1    │
# │ 70005200-01     ┆ 1    │
# │ 82000400-01     ┆ 1    │
# └─────────────────┴──────┘

# %%
indicator_table = water_quality_keys.join(
    xref_keys,
    left_on="DNR_ID_Site_Number",
    right_on="Monit_MAP_CODE1",
    how="outer"
).fill_null(0)
indicator_table
# Out:
# /tmp/ipython-input-1273581701.py:1: DeprecationWarning: use of `how='outer'` should be replaced with `how='full'`.
# (Deprecated in version 0.20.29)
#   indicator_table = water_quality_keys.join(
# shape: (440, 5)
# ┌────────────────────┬───────────┬───────────────┬─────────────────┬──────┐
# │ DNR_ID_Site_Number ┆ LAKE_NAME ┆ water_quality ┆ Monit_MAP_CODE1 ┆ xref │
# │ ---                ┆ ---       ┆ ---           ┆ ---             ┆ ---  │
# │ str                ┆ str       ┆ i32           ┆ str             ┆ i32  │
# ╞════════════════════╪═══════════╪═══════════════╪═════════════════╪══════╡
# │ null               ┆ null      ┆ 0             ┆ 19005100-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 19009500-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 02000900-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 27005700-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 82004800-01     ┆ 1    │
# │ …                  ┆ …         ┆ …             ┆ …               ┆ …    │
# │ null               ┆ null      ┆ 0             ┆ 82009900-02     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 19008200-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 82008000-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 70005200-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 82000400-01     ┆ 1    │
# └────────────────────┴───────────┴───────────────┴─────────────────┴──────┘

# %%
indicator_table.filter(pl.col('xref') == 0)
# Out:
# shape: (0, 5)
# ┌────────────────────┬───────────┬───────────────┬─────────────────┬──────┐
# │ DNR_ID_Site_Number ┆ LAKE_NAME ┆ water_quality ┆ Monit_MAP_CODE1 ┆ xref │
# │ ---                ┆ ---       ┆ ---           ┆ ---             ┆ ---  │
# │ str                ┆ str       ┆ i32           ┆ str             ┆ i32  │
# ╞════════════════════╪═══════════╪═══════════════╪═════════════════╪══════╡
# └────────────────────┴───────────┴───────────────┴─────────────────┴──────┘

# %%
indicator_table.filter(pl.col('water_quality') == 0)
# Out:
# shape: (440, 5)
# ┌────────────────────┬───────────┬───────────────┬─────────────────┬──────┐
# │ DNR_ID_Site_Number ┆ LAKE_NAME ┆ water_quality ┆ Monit_MAP_CODE1 ┆ xref │
# │ ---                ┆ ---       ┆ ---           ┆ ---             ┆ ---  │
# │ str                ┆ str       ┆ i32           ┆ str             ┆ i32  │
# ╞════════════════════╪═══════════╪═══════════════╪═════════════════╪══════╡
# │ null               ┆ null      ┆ 0             ┆ 19005100-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 19009500-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 02000900-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 27005700-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 82004800-01     ┆ 1    │
# │ …                  ┆ …         ┆ …             ┆ …               ┆ …    │
# │ null               ┆ null      ┆ 0             ┆ 82009900-02     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 19008200-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 82008000-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 70005200-01     ┆ 1    │
# │ null               ┆ null      ┆ 0             ┆ 82000400-01     ┆ 1    │
# └────────────────────┴───────────┴───────────────┴─────────────────┴──────┘

# %% [markdown]
# ## Problem 4 - Make an indicator column for the lat/long keys XREF VS parcel files.
#
# To explore mismatches based on the lat/long keys, we will make another indicator table as shown below.
#
# ![image.png](attachment:image.png)
#
# Again, use this table to explore all mismatches.
#
# **Important.** Be sure to read the lat/long columns as strings!

# %%
# Your code here
import re
year_pattern = re.compile(r'(\d{4})_metro_tax_parcels')
getyear = lambda path: (m.group(1) if (m := year_pattern.search(path)) else None)

# %%
from glob import glob
# Find all parcel .txt files in data subfolders using glob
parcel_paths = [
    p
    for p in glob('data/**/*.txt', recursive=True)
    if 'parcel' in p
]
parcel_paths
# Out:
# ['data/MinneMUDAC_raw_files/2015_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2003_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2014_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2009_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2008_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2006_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2007_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2002_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2011_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2013_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2002_metro_tax_parcels_v2.txt',
#  'data/MinneMUDAC_raw_files/2005_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2004_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2010_metro_tax_parcels.txt',
#  'data/MinneMUDAC_raw_files/2012_metro_tax_parcels.txt']

# %%
parcel_lat_long_tables = [
    (
        pl.scan_csv(
            path,
            has_header=True,
            separator="|",
            schema_overrides={"centroid_lat": pl.String(), "centroid_long": pl.String()}
        )
        .select(["centroid_lat", "centroid_long"])
        .unique()
        .with_columns(pl.lit(1).alias(str(getyear(path))))
        .collect()
    )
    for path in parcel_paths
]
parcel_lat_long_tables
# Out:
# [shape: (623_153, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2015 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 44.8898      ┆ -93.56867     ┆ 1    │
#  │ 45.24279     ┆ -93.21048     ┆ 1    │
#  │ 45.13628     ┆ -93.2036      ┆ 1    │
#  │ 45.41226     ┆ -93.47794     ┆ 1    │
#  │ 45.06954     ┆ -93.23157     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 45.07186     ┆ -93.25322     ┆ 1    │
#  │ 44.7964      ┆ -93.2239      ┆ 1    │
#  │ 44.95793     ┆ -93.26036     ┆ 1    │
#  │ 45.08        ┆ -93.26611     ┆ 1    │
#  │ 45.04265     ┆ -93.29892     ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (1_117_593, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2003 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 45.02731     ┆ -93.47195     ┆ 1    │
#  │ 44.71254     ┆ -92.86241     ┆ 1    │
#  │ 44.80713     ┆ -93.12753     ┆ 1    │
#  │ 45.10015     ┆ -93.32558     ┆ 1    │
#  │ 44.89702     ┆ -93.06214     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 45.22792     ┆ -93.42779     ┆ 1    │
#  │ 44.58319     ┆ -93.47253     ┆ 1    │
#  │ 44.71085     ┆ -93.41885     ┆ 1    │
#  │ 44.97298     ┆ -93.08334     ┆ 1    │
#  │ 44.99704     ┆ -93.0582      ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (767_022, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2014 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 44.97551     ┆ -93.0108      ┆ 1    │
#  │ 45.02721     ┆ -93.28535     ┆ 1    │
#  │ 44.96051     ┆ -93.15137     ┆ 1    │
#  │ 45.01157     ┆ -93.24267     ┆ 1    │
#  │ 44.94401     ┆ -93.36259     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 44.74506     ┆ -93.26009     ┆ 1    │
#  │ 44.82899     ┆ -93.80579     ┆ 1    │
#  │ 44.94677     ┆ -93.36469     ┆ 1    │
#  │ 45.19498     ┆ -93.26085     ┆ 1    │
#  │ 45.15955     ┆ -93.26989     ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (214_805, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2009 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 45.15128     ┆ -93.0564      ┆ 1    │
#  │ 45.19557     ┆ -93.18792     ┆ 1    │
#  │ 45.2748      ┆ -93.04027     ┆ 1    │
#  │ 45.10862     ┆ -93.23513     ┆ 1    │
#  │ 44.82033     ┆ -93.01532     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 45.25138     ┆ -93.41671     ┆ 1    │
#  │ 45.17089     ┆ -93.11619     ┆ 1    │
#  │ 45.21006     ┆ -93.23637     ┆ 1    │
#  │ 45.12675     ┆ -93.16837     ┆ 1    │
#  │ 45.15291     ┆ -93.25222     ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (982_347, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2008 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 44.86612     ┆ -93.2488      ┆ 1    │
#  │ 45.16952     ┆ -93.04578     ┆ 1    │
#  │ 44.88464     ┆ -93.37917     ┆ 1    │
#  │ 44.74265     ┆ -93.20684     ┆ 1    │
#  │ 45.02014     ┆ -93.22985     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 44.92792     ┆ -93.2744      ┆ 1    │
#  │ 44.92001     ┆ -93.16413     ┆ 1    │
#  │ 44.95707     ┆ -93.17922     ┆ 1    │
#  │ 45.35443     ┆ -93.34852     ┆ 1    │
#  │ 44.90205     ┆ -93.28922     ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (1_213_849, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2006 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 44.8472      ┆ -93.55549     ┆ 1    │
#  │ 44.70722     ┆ -93.20803     ┆ 1    │
#  │ 44.78125     ┆ -93.21028     ┆ 1    │
#  │ 45.04374     ┆ -92.82553     ┆ 1    │
#  │ 45.11217     ┆ -93.14368     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 44.59676     ┆ -93.26482     ┆ 1    │
#  │ 45.15315     ┆ -93.37722     ┆ 1    │
#  │ 45.35708     ┆ -93.30872     ┆ 1    │
#  │ 45.29408     ┆ -93.29104     ┆ 1    │
#  │ 44.95101     ┆ -93.30118     ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (1_088_175, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2007 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 45.14        ┆ -93.11494     ┆ 1    │
#  │ 44.78171     ┆ -93.25992     ┆ 1    │
#  │ 44.71628     ┆ -92.84165     ┆ 1    │
#  │ 44.96244     ┆ -93.30588     ┆ 1    │
#  │ 45.03206     ┆ -93.42502     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 45.0177      ┆ -93.34051     ┆ 1    │
#  │ 44.83938     ┆ -93.48325     ┆ 1    │
#  │ 44.71521     ┆ -93.1939      ┆ 1    │
#  │ 44.97541     ┆ -93.02624     ┆ 1    │
#  │ 45.32097     ┆ -93.22092     ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (239_366, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2002 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 45.20344     ┆ -93.3942      ┆ 1    │
#  │ 45.0559      ┆ -93.22982     ┆ 1    │
#  │ 44.76184     ┆ -93.62699     ┆ 1    │
#  │ 44.89693     ┆ -93.14299     ┆ 1    │
#  │ 45.15212     ┆ -93.24957     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 44.91701     ┆ -93.08757     ┆ 1    │
#  │ 44.86557     ┆ -93.54467     ┆ 1    │
#  │ 45.10938     ┆ -93.25636     ┆ 1    │
#  │ 45.20843     ┆ -93.09503     ┆ 1    │
#  │ 45.1314      ┆ -93.29164     ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (905_074, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2011 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 45.04525     ┆ -93.38898     ┆ 1    │
#  │ 44.9495      ┆ -93.21564     ┆ 1    │
#  │ 45.13402     ┆ -93.42816     ┆ 1    │
#  │ 44.77026     ┆ -93.25132     ┆ 1    │
#  │ 44.79114     ┆ -93.52886     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 44.83803     ┆ -92.93286     ┆ 1    │
#  │ 45.06977     ┆ -93.42921     ┆ 1    │
#  │ 44.91017     ┆ -93.11414     ┆ 1    │
#  │ 44.98192     ┆ -92.95762     ┆ 1    │
#  │ 44.80408     ┆ -93.12037     ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (732_945, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2013 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 45.00676     ┆ -93.29082     ┆ 1    │
#  │ 45.1993      ┆ -93.22603     ┆ 1    │
#  │ 45.22372     ┆ -93.35093     ┆ 1    │
#  │ 45.14702     ┆ -93.14335     ┆ 1    │
#  │ 44.66175     ┆ -93.03001     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 44.9047      ┆ -92.88802     ┆ 1    │
#  │ 44.79478     ┆ -93.2023      ┆ 1    │
#  │ 44.8604      ┆ -93.58273     ┆ 1    │
#  │ 44.72016     ┆ -93.22218     ┆ 1    │
#  │ 44.75113     ┆ -93.30895     ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (1_103_310, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2002 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 44.92739     ┆ -93.59234     ┆ 1    │
#  │ 45.1805      ┆ -93.15489     ┆ 1    │
#  │ 44.71442     ┆ -93.22453     ┆ 1    │
#  │ 45.11093     ┆ -93.31291     ┆ 1    │
#  │ 44.8225      ┆ -93.39511     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 44.93001     ┆ -93.17776     ┆ 1    │
#  │ 44.95591     ┆ -93.19548     ┆ 1    │
#  │ 45.20424     ┆ -93.31418     ┆ 1    │
#  │ 44.95714     ┆ -93.41939     ┆ 1    │
#  │ 45.00267     ┆ -92.9885      ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (1_421_754, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2005 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 45.10333     ┆ -93.31764     ┆ 1    │
#  │ 45.01007     ┆ -93.47784     ┆ 1    │
#  │ 44.97165     ┆ -93.12716     ┆ 1    │
#  │ 44.75059     ┆ -93.1947      ┆ 1    │
#  │ 44.82885     ┆ -93.15588     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 44.86294     ┆ -92.84797     ┆ 1    │
#  │ 44.80425     ┆ -93.16352     ┆ 1    │
#  │ 44.84358     ┆ -93.11516     ┆ 1    │
#  │ 44.90943     ┆ -93.24773     ┆ 1    │
#  │ 45.02244     ┆ -92.98806     ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (1_423_149, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2004 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 45.10947     ┆ -93.44864     ┆ 1    │
#  │ 44.7875      ┆ -93.52727     ┆ 1    │
#  │ 44.82471     ┆ -92.94582     ┆ 1    │
#  │ 44.9669      ┆ -93.46756     ┆ 1    │
#  │ 44.74097     ┆ -93.15511     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 44.92688     ┆ -92.94098     ┆ 1    │
#  │ 45.01073     ┆ -93.02691     ┆ 1    │
#  │ 44.71187     ┆ -93.70555     ┆ 1    │
#  │ 45.06262     ┆ -93.28808     ┆ 1    │
#  │ 44.90661     ┆ -92.95468     ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (179_227, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2010 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 44.70906     ┆ -93.21559     ┆ 1    │
#  │ 45.13096     ┆ -93.17021     ┆ 1    │
#  │ 45.32845     ┆ -93.24332     ┆ 1    │
#  │ 45.39633     ┆ -93.35157     ┆ 1    │
#  │ 45.22346     ┆ -93.20196     ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 45.39465     ┆ -93.33848     ┆ 1    │
#  │ 44.89051     ┆ -93.56679     ┆ 1    │
#  │ 45.14533     ┆ -93.17356     ┆ 1    │
#  │ 45.19112     ┆ -93.22145     ┆ 1    │
#  │ 45.12109     ┆ -93.23088     ┆ 1    │
#  └──────────────┴───────────────┴──────┘,
#  shape: (875_410, 3)
#  ┌──────────────┬───────────────┬──────┐
#  │ centroid_lat ┆ centroid_long ┆ 2012 │
#  │ ---          ┆ ---           ┆ ---  │
#  │ str          ┆ str           ┆ i32  │
#  ╞══════════════╪═══════════════╪══════╡
#  │ 45.11909     ┆ -93.24208     ┆ 1    │
#  │ 44.90268     ┆ -93.31282     ┆ 1    │
#  │ 44.90131     ┆ -93.29175     ┆ 1    │
#  │ 45.14671     ┆ -93.25701     ┆ 1    │
#  │ 45.12674     ┆ -93.1652      ┆ 1    │
#  │ …            ┆ …             ┆ …    │
#  │ 45.02695     ┆ -93.41287     ┆ 1    │
#  │ 45.06508     ┆ -93.0256      ┆ 1    │
#  │ 45.08566     ┆ -93.12472     ┆ 1    │
#  │ 45.24695     ┆ -92.78016     ┆ 1    │
#  │ 44.95425     ┆ -93.1104      ┆ 1    │
#  └──────────────┴───────────────┴──────┘]

# %%
join_next = lambda left, right: (
    left.join(
        right,
        on=['centroid_lat', 'centroid_long'],
        how='full'
    )
    .drop(cs.ends_with('_right'))
)
join_next
# Out:
# <function __main__.<lambda>(left, right)>

# %%
test_join = join_next(parcel_lat_long_tables[0], parcel_lat_long_tables[1])
test_join
# Out:
# shape: (1_580_184, 4)
# ┌──────────────┬───────────────┬──────┬──────┐
# │ centroid_lat ┆ centroid_long ┆ 2015 ┆ 2003 │
# │ ---          ┆ ---           ┆ ---  ┆ ---  │
# │ str          ┆ str           ┆ i32  ┆ i32  │
# ╞══════════════╪═══════════════╪══════╪══════╡
# │ null         ┆ null          ┆ null ┆ 1    │
# │ 44.71254     ┆ -92.86241     ┆ 1    ┆ 1    │
# │ null         ┆ null          ┆ null ┆ 1    │
# │ null         ┆ null          ┆ null ┆ 1    │
# │ null         ┆ null          ┆ null ┆ 1    │
# │ …            ┆ …             ┆ …    ┆ …    │
# │ 44.82633     ┆ -93.62458     ┆ 1    ┆ null │
# │ 45.06131     ┆ -93.23437     ┆ 1    ┆ null │
# │ 45.10877     ┆ -93.42588     ┆ 1    ┆ null │
# │ 45.16269     ┆ -93.31598     ┆ 1    ┆ null │
# │ 45.01404     ┆ -93.31296     ┆ 1    ┆ null │
# └──────────────┴───────────────┴──────┴──────┘

# %%
join_next(parcel_lat_long_tables[0], parcel_lat_long_tables[1])
# Out:
# shape: (1_580_184, 4)
# ┌──────────────┬───────────────┬──────┬──────┐
# │ centroid_lat ┆ centroid_long ┆ 2015 ┆ 2003 │
# │ ---          ┆ ---           ┆ ---  ┆ ---  │
# │ str          ┆ str           ┆ i32  ┆ i32  │
# ╞══════════════╪═══════════════╪══════╪══════╡
# │ null         ┆ null          ┆ null ┆ 1    │
# │ 44.71254     ┆ -92.86241     ┆ 1    ┆ 1    │
# │ null         ┆ null          ┆ null ┆ 1    │
# │ null         ┆ null          ┆ null ┆ 1    │
# │ null         ┆ null          ┆ null ┆ 1    │
# │ …            ┆ …             ┆ …    ┆ …    │
# │ 45.13087     ┆ -93.03296     ┆ 1    ┆ null │
# │ 44.92502     ┆ -93.31644     ┆ 1    ┆ null │
# │ 44.98845     ┆ -93.57151     ┆ 1    ┆ null │
# │ 44.99995     ┆ -93.46704     ┆ 1    ┆ null │
# │ 45.18851     ┆ -93.22483     ┆ 1    ┆ null │
# └──────────────┴───────────────┴──────┴──────┘

# %%
xref_lat_long_table = (
    pl.scan_csv(
        'data/MinneMUDAC_raw_files/Parcel_Lake_Monitoring_Site_Xref.txt',
        has_header=True,
        separator='\t',
        schema_overrides={'centroid_lat': pl.String(), 'centroid_long': pl.String()}
    )
    .select(['centroid_lat', 'centroid_long'])
    .unique()
    .with_columns([pl.lit(1).alias('xref')])
    .collect()
)
xref_lat_long_table
# Out:
# shape: (1_728_195, 3)
# ┌──────────────┬───────────────┬──────┐
# │ centroid_lat ┆ centroid_long ┆ xref │
# │ ---          ┆ ---           ┆ ---  │
# │ str          ┆ str           ┆ i32  │
# ╞══════════════╪═══════════════╪══════╡
# │ 44.67569     ┆ -93.17771     ┆ 1    │
# │ 44.6851      ┆ -93.1849      ┆ 1    │
# │ 45.17863     ┆ -93.32701     ┆ 1    │
# │ 44.7522      ┆ -93.31079     ┆ 1    │
# │ 45.01533     ┆ -93.38504     ┆ 1    │
# │ …            ┆ …             ┆ …    │
# │ 44.69524     ┆ -92.75605     ┆ 1    │
# │ 44.66848     ┆ -93.25337     ┆ 1    │
# │ 45.12686     ┆ -93.24995     ┆ 1    │
# │ 44.88319     ┆ -93.46483     ┆ 1    │
# │ 44.79022     ┆ -93.53547     ┆ 1    │
# └──────────────┴───────────────┴──────┘

# %%
from functools import reduce
# Reduce parcel indicator tables with join_next, starting from xref_latlong_table
final_indicator_table = (
    reduce(
        join_next,
        parcel_lat_long_tables,
        xref_lat_long_table
    )
    .filter(~(pl.col('centroid_lat').is_null() | pl.col('centroid_long').is_null()))
    .fill_null(0)
    .drop(['2002', '2003'])
    .with_columns(total_years = pl.sum_horizontal(cs.starts_with('20')))
)
final_indicator_table
# Out:
# shape: (1_728_195, 16)
# ┌──────────────┬───────────────┬──────┬──────┬───┬──────┬──────┬──────┬─────────────┐
# │ centroid_lat ┆ centroid_long ┆ xref ┆ 2015 ┆ … ┆ 2004 ┆ 2010 ┆ 2012 ┆ total_years │
# │ ---          ┆ ---           ┆ ---  ┆ ---  ┆   ┆ ---  ┆ ---  ┆ ---  ┆ ---         │
# │ str          ┆ str           ┆ i32  ┆ i32  ┆   ┆ i32  ┆ i32  ┆ i32  ┆ i32         │
# ╞══════════════╪═══════════════╪══════╪══════╪═══╪══════╪══════╪══════╪═════════════╡
# │ 44.67569     ┆ -93.17771     ┆ 1    ┆ 1    ┆ … ┆ 1    ┆ 0    ┆ 1    ┆ 11          │
# │ 44.6851      ┆ -93.1849      ┆ 1    ┆ 0    ┆ … ┆ 1    ┆ 0    ┆ 0    ┆ 4           │
# │ 45.17863     ┆ -93.32701     ┆ 1    ┆ 0    ┆ … ┆ 1    ┆ 0    ┆ 0    ┆ 4           │
# │ 44.7522      ┆ -93.31079     ┆ 1    ┆ 1    ┆ … ┆ 1    ┆ 0    ┆ 1    ┆ 10          │
# │ 45.01533     ┆ -93.38504     ┆ 1    ┆ 0    ┆ … ┆ 1    ┆ 0    ┆ 0    ┆ 3           │
# │ …            ┆ …             ┆ …    ┆ …    ┆ … ┆ …    ┆ …    ┆ …    ┆ …           │
# │ 44.69524     ┆ -92.75605     ┆ 1    ┆ 0    ┆ … ┆ 1    ┆ 0    ┆ 1    ┆ 8           │
# │ 44.66848     ┆ -93.25337     ┆ 1    ┆ 1    ┆ … ┆ 1    ┆ 0    ┆ 1    ┆ 10          │
# │ 45.12686     ┆ -93.24995     ┆ 1    ┆ 1    ┆ … ┆ 1    ┆ 1    ┆ 1    ┆ 12          │
# │ 44.88319     ┆ -93.46483     ┆ 1    ┆ 0    ┆ … ┆ 1    ┆ 0    ┆ 0    ┆ 5           │
# │ 44.79022     ┆ -93.53547     ┆ 1    ┆ 0    ┆ … ┆ 0    ┆ 0    ┆ 0    ┆ 2           │
# └──────────────┴───────────────┴──────┴──────┴───┴──────┴──────┴──────┴─────────────┘

# %%
final_indicator_table.filter(pl.col('xref') == 0)
# Out:
# shape: (0, 16)
# ┌──────────────┬───────────────┬──────┬──────┬───┬──────┬──────┬──────┬─────────────┐
# │ centroid_lat ┆ centroid_long ┆ xref ┆ 2015 ┆ … ┆ 2004 ┆ 2010 ┆ 2012 ┆ total_years │
# │ ---          ┆ ---           ┆ ---  ┆ ---  ┆   ┆ ---  ┆ ---  ┆ ---  ┆ ---         │
# │ str          ┆ str           ┆ i32  ┆ i32  ┆   ┆ i32  ┆ i32  ┆ i32  ┆ i32         │
# ╞══════════════╪═══════════════╪══════╪══════╪═══╪══════╪══════╪══════╪═════════════╡
# └──────────────┴───────────────┴──────┴──────┴───┴──────┴──────┴──────┴─────────────┘

# %%
final_indicator_table.filter(pl.col('total_years') == 0)
# Out:
# shape: (125_220, 16)
# ┌──────────────┬───────────────┬──────┬──────┬───┬──────┬──────┬──────┬─────────────┐
# │ centroid_lat ┆ centroid_long ┆ xref ┆ 2015 ┆ … ┆ 2004 ┆ 2010 ┆ 2012 ┆ total_years │
# │ ---          ┆ ---           ┆ ---  ┆ ---  ┆   ┆ ---  ┆ ---  ┆ ---  ┆ ---         │
# │ str          ┆ str           ┆ i32  ┆ i32  ┆   ┆ i32  ┆ i32  ┆ i32  ┆ i32         │
# ╞══════════════╪═══════════════╪══════╪══════╪═══╪══════╪══════╪══════╪═════════════╡
# │ 45.059       ┆ -92.98129     ┆ 1    ┆ 0    ┆ … ┆ 0    ┆ 0    ┆ 0    ┆ 0           │
# │ 45.22142     ┆ -93.22728     ┆ 1    ┆ 0    ┆ … ┆ 0    ┆ 0    ┆ 0    ┆ 0           │
# │ 45.14041     ┆ -92.79815     ┆ 1    ┆ 0    ┆ … ┆ 0    ┆ 0    ┆ 0    ┆ 0           │
# │ 44.92688     ┆ -93.38634     ┆ 1    ┆ 0    ┆ … ┆ 0    ┆ 0    ┆ 0    ┆ 0           │
# │ 45.03322     ┆ -92.82467     ┆ 1    ┆ 0    ┆ … ┆ 0    ┆ 0    ┆ 0    ┆ 0           │
# │ …            ┆ …             ┆ …    ┆ …    ┆ … ┆ …    ┆ …    ┆ …    ┆ …           │
# │ 44.96764     ┆ -93.35587     ┆ 1    ┆ 0    ┆ … ┆ 0    ┆ 0    ┆ 0    ┆ 0           │
# │ 44.69202     ┆ -93.44948     ┆ 1    ┆ 0    ┆ … ┆ 0    ┆ 0    ┆ 0    ┆ 0           │
# │ 45.01544     ┆ -93.25757     ┆ 1    ┆ 0    ┆ … ┆ 0    ┆ 0    ┆ 0    ┆ 0           │
# │ 45.08942     ┆ -93.41768     ┆ 1    ┆ 0    ┆ … ┆ 0    ┆ 0    ┆ 0    ┆ 0           │
# │ 45.03524     ┆ -92.8023      ┆ 1    ┆ 0    ┆ … ┆ 0    ┆ 0    ┆ 0    ┆ 0           │
# └──────────────┴───────────────┴──────┴──────┴───┴──────┴──────┴──────┴─────────────┘
